# %%
# Import Pakage
import seaborn as sns
import numpy as np
from modul.model import boostraping
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
sample = [7, 11, 8, 30]

# %%
resample,mean_resample,var_mean_resample,mse_mean_resample,ci_mean_resample=boostraping(sample,1000,70).mean_bootsrap()
print('Real Mean :',np.mean(sample))
print('Mean Re-Sample:{:.3f}'.format(mean_resample))
print('MSE Re-sample:{:.3f}'.format(mse_mean_resample))
print('CI Re-sample:{}'.format(ci_mean_resample))
# Out:
# =======Start Bootstarp========
# ========End Bootstarp=========
# Real Mean : 14.0
# Mean Re-Sample:14.001
# MSE Re-sample:0.909
# CI Re-sample:[11.768183398373813, 16.231816601626186]

# %%
fig,ax=plt.subplots(1,2,figsize=(20,10))
ax[0].set_title('Distribution Sample without Boostrap')
sns.distplot(sample,ax=ax[0])
ax[1].set_title('Distribution Sample with Boostrap')
sns.distplot(resample,ax=ax[1])
# ax[1].set_title()
# Out:
# /tmp/ipykernel_8825/2139632031.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#
# /tmp/ipykernel_8825/2139632031.py:5: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: title={'center': 'Distribution Sample with Boostrap'}, ylabel='Density'>

# %%
sample2 = np.random.chisquare(5, 100)
resample, mean_resample,_,_,_= boostraping(list(sample2), rows=1000, k=70).mean_bootsrap()
sns.distplot(resample)
plt.show()
print("Mean Bootstrap: ", mean_resample)
sns.distplot(sample2)
# Out:
# =======Start Bootstarp========
# ========End Bootstarp=========
# /tmp/ipykernel_8825/3457904889.py:3: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Mean Bootstrap:  4.972798646461394
# /tmp/ipykernel_8825/3457904889.py:6: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# ...

# %%
_,var_resample=boostraping(list(sample),k=70,rows=1000).variance()
sns.distplot(list(sample))
# print(np.var(list(sampel)))
# sns.distplot(var_resample)
# print(var_resample)
# Out:
# /tmp/ipykernel_8825/949108141.py:2: UserWarning:
#
#
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# <AxesSubplot: ylabel='Density'>

# %% [markdown]
# > ## Source Code Ini Disimpan di :
# > https://github.com/kayabaakihiko13/computation_of_statics/tree/main/Week7/Task
# tolong kasih bintangnya pak  😅🙏
