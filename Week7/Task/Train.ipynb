# %%
# Import Pakage
import seaborn as sns
import numpy as np
from boostraping.model import boostraping
# from model.modeling import statistic
import matplotlib.pyplot as plt


# import plotly.express as px
# %matplotlib inline

# %%
sample = ([7, 11, 8, 30])

# %%
resample_mean,mean_resample,var_mean_resample,mse_mean_resample,ci_mean_resample=boostraping(sample,1000,70).mean_bootsrap()
print('Real Mean :',np.mean(sample))
print('Mean Re-Sample:{:.3f}'.format(mean_resample))
print('MSE Re-sample:{:.3f}'.format(mse_mean_resample))
print('CI Re-sample:{}'.format(ci_mean_resample))
# Out:
# =======Start Bootstarp========
# ========End Bootstarp=========
# Real Mean : 14.0
# Mean Re-Sample:13.962
# MSE Re-sample:0.910
# CI Re-sample:[11.761432165176988, 16.238567834823012]

# %%
# Out:
# array([15.41428571, 12.91428571, 13.32857143, 13.7       , 16.05714286,
#        14.71428571, 13.17142857, 14.04285714, 15.75714286, 16.35714286,
#        14.6       , 14.44285714, 15.87142857, 14.28571429, 13.5       ,
#        13.78571429, 15.88571429, 14.54285714, 13.92857143, 14.04285714,
#        13.25714286, 13.08571429, 13.84285714, 13.78571429, 15.54285714,
#        13.95714286, 12.        , 13.7       , 15.27142857, 11.68571429,
#        12.51428571, 13.65714286, 13.17142857, 13.64285714, 14.14285714,
#        13.1       , 15.32857143, 15.5       , 15.62857143, 15.64285714,
#        15.15714286, 14.85714286, 16.21428571, 14.17142857, 13.48571429,
#        12.48571429, 14.34285714, 13.15714286, 13.54285714, 13.6       ,
#        14.97142857, 13.41428571, 12.71428571, 13.3       , 12.5       ,
#        14.54285714, 13.21428571, 13.54285714, 15.28571429, 14.32857143,
#        13.02857143, 13.6       , 12.24285714, 13.24285714, 13.75714286,
# ...

# %%
fig,ax=plt.subplots(1,2,figsize=(20,10))
ax[0].set_title('Distribution Sample without Boostrap')
sns.distplot(sample,ax=ax[0])
ax[1].set_title('Distribution Sample with Boostrap')
sns.distplot(resample,ax=ax[1])
# ax[1].set_title()
# Out:
# /tmp/ipykernel_7571/2139632031.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(sample,ax=ax[0])
# /tmp/ipykernel_7571/2139632031.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(resample,ax=ax[1])
# ...

# %%
sample2 = np.random.chisquare(5, 100)
resample_mean, mean_resample,_,_,_= boostraping(list(sample2), rows=1000, k=70).mean_bootsrap()
sns.distplot(resample_mean)
plt.show()
print("Mean Bootstrap: ", mean_resample)
sns.distplot(sample2)
# Out:
# =======Start Bootstarp========
# ========End Bootstarp=========
# /tmp/ipykernel_7571/476048620.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(resample_mean)
# Mean Bootstrap:  5.001945837844154
# /tmp/ipykernel_7571/476048620.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %%
_,var_resample=boostraping(list(sample),k=70,rows=1000).variance()
sns.distplot(list(sample))
# print(np.var(list(sampel)))
# sns.distplot(var_resample)
# print(var_resample)
# Out:
# /tmp/ipykernel_7571/949108141.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(list(sample))
# <AxesSubplot: ylabel='Density'>

# %%
resample,median_resample,_,_,_=boostraping(sample,rows=1000,k=70).median_bootrap()
print('median real',np.median(sample))
print('median Fake',median_resample)
# Out:
# median real 9.5
# median Fake 9.6125

# %%
def jackknife_stat(data,func,convince=.95):
    "Data its Resample"
    '''
    Full Refence:
    https://docs.astropy.org/en/stable/api/astropy.stats.jackknife_stats.html
    https://docs.astropy.org/en/stable/_modules/astropy/stats/jackknife.html#jackknife_stats
    '''

    dummy=data.copy()
    dummy=np.array(dummy)
    n=dummy.shape[0]
    resamples = np.empty([n, n-1])
    for i in range(n):
        resamples[i] = np.delete(data, i)

    
    if not (0<convince<1):
        raise ValueError('tidak bisa')
    if n<=0:
        raise ValueError('data must contain at least one measurement.')
    # import erfinv
    from scipy.special import erfinv
    stat_data = func(data)
    jack_stat = np.apply_along_axis(func, 1, resamples)
    mean_jack_stat = np.mean(jack_stat, axis=0)
    bias = (n-1)*(mean_jack_stat - stat_data)
    std_err = np.sqrt((n-1)*np.mean((jack_stat - mean_jack_stat)*(jack_stat -
                                    mean_jack_stat), axis=0))
    estimate = stat_data - bias

    z_score = np.sqrt(2.0)*erfinv(convince)
    convince = estimate + z_score*np.array((-std_err, std_err))

    return estimate, bias, std_err, convince

# %%
# jackknife_resampilng(resample_mean)
jackknife_stat(resample_mean,np.mean)
# Out:
# (5.001945837844154, 0.0, 0.011355405837299593, array([4.97968965, 5.02420202]))

# %%
jackknife_stat(resample_mean,np.mean)
# Out:
# (5.001945837844154, 0.0, 0.011355405837299593, array([4.97968965, 5.02420202]))

# %% [markdown]
# > ## Source Code Ini Disimpan di :
# > https://github.com/kayabaakihiko13/computation_of_statics/tree/main/Week7/Task
# tolong kasih bintangnya pak  😅🙏
