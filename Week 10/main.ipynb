# %%
from model.stats import random_uniform
import numpy as np
from math import pi
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test_function=random_uniform(0,1,1000)
numpy_randn=np.random.randn(0,1,100)
sns.distplot(test_function)
# sns.displot(numpy_randn)
plt.show()
# Out:
# /tmp/ipykernel_8307/1178217534.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(test_function)

# %%
a=random_uniform(-1,1,1000)
b=random_uniform(-1,1,1000)
s2=np.array(a)**2+np.array(b)**2
theta_hat=sum(s2<1)/1000
theta_hat*=4
print(f'phi predict:{theta_hat}')
print(f'phi True:{pi}')
sns.scatterplot(s2)
# Out:
# phi predict:3.124
# phi True:3.141592653589793
# <AxesSubplot: >

# %% [markdown]
# <h2>Refence</h2>
# <ul>
#     <li>https://numpy.org/doc/stable/reference/generated/numpy.exp.html<li>
# </ul>
